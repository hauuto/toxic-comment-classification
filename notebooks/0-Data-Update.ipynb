# %% [markdown]
# Notebook này dùng để cập nhật data của nhau thông qua Google Drive

# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('__file__'))))

from src import google_drive
import importlib

# %% [markdown]
# Cập nhật upload data lên drive sau khi code xong

# %%
importlib.reload(google_drive)
google_drive.upload_all_data()
# Out:
# Bat dau upload tu: ../data
# Dang upload: Bac_ky_5_30_processed.csv...
# Xong: Bac_ky_5_30_processed.csv
# Dang upload: Bake_5_30_processed.csv...
# Xong: Bake_5_30_processed.csv
# Dang upload: BKAV_5_30_processed.csv...
# Xong: BKAV_5_30_processed.csv
# Dang upload: Boc_phot_5_30_processed.csv...
# Xong: Boc_phot_5_30_processed.csv
# Bo qua (da co): combined_processed.csv
# Dang upload: combined_text_only.csv...
# Xong: combined_text_only.csv
# Dang upload: Com_suon_5_30_processed.csv...
# Xong: Com_suon_5_30_processed.csv
# Dang upload: Co_nau_5_30_processed.csv...
# Xong: Co_nau_5_30_processed.csv
# Dang upload: dictionary_rebuilt.txt...
# Xong: dictionary_rebuilt.txt
# Bo qua (da co): eLcYOrgGl-A_processed.csv
# Bo qua (da co): IzSYlr3VI1A_processed.csv
# Dang upload: Luong_lap_trinh_vien_5_30_processed.csv...
# Xong: Luong_lap_trinh_vien_5_30_processed.csv
# Dang upload: Me_Tay_5_30_processed.csv...
# Xong: Me_Tay_5_30_processed.csv
# Bo qua (da co): QBvL3Ffn1u4_processed.csv
# ...

# %% [markdown]
# Fetch tất cả data mới về

# %%
importlib.reload(google_drive)
google_drive.fetch_data()
# Out:
# Bat dau dong bo tu Drive (1GkjNZ3QeD_tsOZLBHq7fhMw9yVzEc1Os) ve (../data)...
# Bo qua (da co): Vin_no_5_30_processed.csv
# Bo qua (da co): Vin_5_30_processed.csv
# Bo qua (da co): TNT_5_30_processed.csv
# Bo qua (da co): That_nghiep_5_30_processed.csv
# Bo qua (da co): Ro_Nga_5_30_processed.csv
# Bo qua (da co): Me_Tay_5_30_processed.csv
# Bo qua (da co): Luong_lap_trinh_vien_5_30_processed.csv
# Bo qua (da co): dictionary_rebuilt.txt
# Bo qua (da co): Co_nau_5_30_processed.csv
# Bo qua (da co): Com_suon_5_30_processed.csv
# Bo qua (da co): combined_text_only.csv
# Bo qua (da co): Boc_phot_5_30_processed.csv
# Bo qua (da co): BKAV_5_30_processed.csv
# Bo qua (da co): Bake_5_30_processed.csv
# Bo qua (da co): Bac_ky_5_30_processed.csv
# Bo qua (da co): Ym6h7ZLtdhE_processed.csv
# Bo qua (da co): x5CNJUMJcII_processed.csv
# Bo qua (da co): qGRU3sRbaYw_processed.csv
# Bo qua (da co): QBvL3Ffn1u4_processed.csv
# Bo qua (da co): IzSYlr3VI1A_processed.csv
# ...
