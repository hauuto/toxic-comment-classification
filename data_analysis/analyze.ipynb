# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../reports/labeled_data.csv")
data.head(5)
# Out:
#    id                                               text    label
# 0   0  Bon con trai lop mình suot ngay: " CHÚNG_TA KH...    Clean
# 1   1  Hát chối tai quá. Autotone rồi mà quá quá quá ...    Clean
# 2   2  chị chi pu ơi thường tuấn sồm nó vả mồm em chị...  Obscene
# 3   3  cảm_ơn quí, từ ngày bị chê béo, tôi nghe bài n...    Clean
# 4   4           tôi vào đây chỉ để không thích = ) ) ) )    Clean

# %%
data['label'].value_counts()
# Out:
# label
# Clean          6478
# Obscene         789
# Spam            292
# Hate Speech     143
# Harassment       33
# Name: count, dtype: int64
