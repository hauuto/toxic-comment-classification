# %%
import pandas as pd

# %%
df = pd.read_csv(r"K:\GithubRepo\comment-classification\data\combined_processed.csv")
df.drop(columns=['no', 'no1', 'source'], inplace=True)

df = df.sample(n=5000, random_state=42)
df.reset_index(drop=True, inplace=True)
df.to_csv("data.csv", index=True, index_label="no", encoding='utf-8-sig')
